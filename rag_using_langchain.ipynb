# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# !pip install -q youtube-transcript-api langchain-community langchain-google-genai faiss-cpu tiktoken python-dotenv langchain-ollama
# Out:
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\MSI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\MSI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\MSI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: C:\Users\MSI\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_ollama import ChatOllama, OllamaEmbeddings
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_16488\3545689688.py:5: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS

# %%
video_id = "jRKVICXncRk"

try:
    transcript_list = YouTubeTranscriptApi().fetch(video_id, languages=["hi"])

    transcript = " ".join(chunk.text for chunk in transcript_list)
    # print(type(transcript_list))
    print(transcript)

except TranscriptsDisabled:
    print("No caption avalable for this video")
# Out:
# दोस्तों अगर आप ओपन सोर्स मॉडल्स को लोकली अपने सिस्टम पे यूज करना चाहते हैं तो ओलामा एक बहुत अच्छा ऑप्शन हो सकता है आपके लिए। यह इजी टू सेटअप है। बिगिनर फ्रेंडली है एंड द बेस्ट पार्ट इज कि आप फ्री में यूज कर सकते हैं। लिटरली आपको ₹1 पे करने का जरूरत नहीं है लोकली मॉडल्स को यूज़ करने के लिए। और आज इस वीडियो में मैं आपको स्टेप बाय स्टेप दिखाऊंगा कि कैसे आप ओलामा यूज कर सकते हैं। कैसे आप ओपन सोर्स मॉडल के साथ चैट कर सकते हैं। मॉडल्स को कैसे डाउनलोड कर सकते हो, रिमूव कर सकते हैं और बहुत कुछ। तो वीडियो एंड तक देखना और कुछ नया सीखने को मिले तो हिट द लाइक बटन एंड सब्सक्राइब फॉर मोर सच वीडियोस। फिलहाल चलो शुरू करते हैं। सबसे पहले तो olलामा एक सॉफ्टवेयर है जो आपको डाउनलोड करना होगा और अपने सिस्टम पे इंस्टॉल करना होगा। उसके लिए आपको सीधा आना है olamma.com पे लिंक आपको नीचे डिस्क्रिप्शन में मिल जाएगा। यहां पे आओगे तो आपके पास दो ऑप्शन है ओलामा इंस्टॉल करने का। सबसे पहला है कि आपको जो यहां कमांड दिखा रहा है सिंपली कॉपी करो और अपने टर्मिनल पे जाके इसको एंटर करो। ऑटोमेटिकली ओलामा इंस्टॉल कर देगा। अगर आपको नहीं मालूम कि टर्मिनल कैसे यूज़ करना है तो आप यहां डाउनलोड ओलामा लिंक पे क्लिक करके जो भी ऑपरेटिंग सिस्टम आप यूज़ करते हो उसके बेसिस पे डाउनलोड कर सकते हो। जैसे Mac OS का यहां पे है। अगर Windows यूज़ करते हो तो Windows के लिए भी आपको यहां पे डाउनलोड बटन मिल जाएगा। आप सॉफ्टवेयर डाउनलोड करो और इंस्टॉल कर लो। Windows के लिए कंपैटिबल है Windows 10 एंड लेटर। अगर आप Windows 7 या 8 यूज़ करते हैं तो आप Olam यूज़ नहीं कर सकते हैं। ठीक है? फिलहाल मैं Mac OS यूज़ कर रहा हूं। तो सो ले
आपके सिस्टम में उसके बेसिस पे अगर आपका सिस्टम का रैम कम है ग्राफिक्स कम है तो हो सकता है कि यही मॉडल बहुत स्लो रिस्पांस भी देगा अब क्योंकि jेमा 4 एक विज़न मॉडल है मतलब कि उसका पास इमेज और डॉक्यूमेंट्स को एनालाइज करने का एबिलिटीज़ है तो यहां पे मैं इमेजज़ भी अपलोड कर सकता हूं। जैसे कि मैं यहां पे ये वाल ...

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size = 3000, chunk_overlap=300)
chunks = splitter.create_documents([transcript])

print(len(chunks))
# Out:
# 7

# %%
embeddings = OllamaEmbeddings(
    model="nomic-embed-text"
)
vector_store = FAISS.from_documents(chunks, embeddings)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '6e2d5a3c-2bec-410e-8a5c-d6b21722b72b',
#  1: 'f5e5f16c-f42f-43ed-a458-5cbb62815b48',
#  2: 'fb962b42-76f0-4f00-ab68-80a16dcd80bb',
#  3: '85d9e564-71ca-40f1-a8a3-37022aca0d00',
#  4: 'd8e732c6-a826-4a8e-b048-a299d17d7ba8',
#  5: '247b6244-7a61-4848-824f-c7d0510a6bc0',
#  6: '4b84871c-e3bf-4cd6-bad9-335530d8602b'}

# %%
vector_store.get_by_ids(['9291fe55-9c97-47b5-aa9d-e6ed733eaf8c'])
# Out:
# []

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k":3})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OllamaEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x000001D51FD35BE0>, search_kwargs={'k': 3})

# %%
retriever.invoke("Is there any charges on Ollama?")
# Out:
# [Document(id='fb962b42-76f0-4f00-ab68-80a16dcd80bb', metadata={}, page_content='को यूज़ कर सकते हो। इस मॉडल से कंटीन्यूअसली चैट कर सकते हो। अब क्योंकि इस मॉडल को मैंने लोकली अपने सिस्टम पे डाउनलोड कर लिया है। तो अब मुझे इसको यूज़ करने के लिए इंटरनेट का जरूरत ही नहीं है। लेट मी टर्न ऑफ माय Wi-Fi। ठीक है? Wi-Fi बंद करता हूं। और अब मैं यहां बोलता हूं एक्सप्लेन व्हाट इज़ एi। ठीक है? और देखो यहां पे कितना फास्ट ये पूरा रिस्पांस दे रहा है। इंटरनेट का मुझे जरूरत ही नहीं है। राइट? सो आपको अब एआई यूज़ करने के लिए सिर्फ बिजली बिल पे करना है और ऑब्वियसली अपने सिस्टम का प्राइस कोई एपीआई का प्राइस जरूरत नहीं है पे करने का ना ही सब्सक्रिप्शन फीस ऑब्वियसली अब ये जो ओपन सोर्स मॉडल्स हैं वो अभी उतने पावरफुल नहीं है जैसे GPT 5.4 है या OPS 4.6 है बट होपफुली धीरे-धीरे आते रहेगा। जैसे यहां पे JMA 4 जो है वो अब तक का सबसे पावरफुल ओपन सोर्स एi मॉडल है जो साइज में भी छोटा है। आप स्मूथली अपने सिस्टम पे डाउनलोड करके यूज कर सकते हो। अभी तक आपने देखा कितनी आसानी से आप olलामा पे ओपन सोर्स मॉडल्स को डाउनलोड करके उनसे चैट कर सकते हो। वो भी बिना इंटरनेट का। पर हर ओपन सोर्स मॉडल इतना छोटा नहीं होता है। कई मॉडल्स बहुत बड़े-बड़े होते हैं साइज में जो आप अपने सिस्
पर अगर मैं यहां पे सर्च करूं तो आपको यहां पे मिल जाएगा। ठीक है? तो एग्जैक्टली जो मॉडल का नाम है जैसे यहां पे यह मॉडल का मॉडल है। लेट्स कॉपी दिस और अब अगर मैं यहां पे सर्च करूंगा तो ये मॉडल भी मुझे यहां पे मिल जाएगा। और इसका क्लाउड मोड भी है। क्लाउड वर्जन भी अवेलेबल है जो मैं यहां पे यूज़ कर सकता हूं। ठीक है? सो आपको यहां पे जितने भी मॉडल्स देखने को मिलेंगे ये सभी मॉडल्स आप यहां पे डाउनलोड करके यूज़ कर सकते हो। और हमेशा मैं सजेस्ट करूंगा कि यहां पे जरूर एक्सप्लोर करना क्योंकि आप देखो यहां पे jमा 4 पे आते हो ना तो आपको पूरा डिटेल मिलेगा इसका कि jमा 4 मॉडल क्या है? उसमें क्या-क्या कैबिलिटीज है? विज़न है, टूल यूज़ कर सकते हो। मतलब कि एजेंटिक वर्क फ्लोस का कैबिलिटीज़ है, थिंकिंग मॉडल है, ऑडियो भी आप इसमें दे सकते हो। फिर ये क्लाउड मोड में भी अवेलेबल है। और इसके चार वेरिएंट्स हैं। और फिर अगर आप नीचे आओगे, देखोगे कि हर वेरिएंट का जो साइज है, वह भी आप देख सकते हो। जो JMA 431B है वो 20GB का है। आप इसको अगर यूज़ करना चाहते हो लोकली तो ऑब्वियसली आपको बहुत ज्यादा जीpu पावर चाहिए होगा। ठीक है? और फिर इसमें देख सकते हो किस तरह का इनपुट दे सकते हो टेक्स्ट और इमेज का। ठीक है? इसी तरीके से अगर मैं यहां पे आ जाऊं कॉइन 3.5 पे तो आप देखो कि यहां पे कितने सारे और भी मॉडल्स हैं और जो इसका सबसे छोटा मॉडल है वो 0.8 का है जो सिर्फ 1GB का है। आप इसको ऑब्वियसली अपने लैपटॉप पे तो रन कर ही सकते हो। कितना भी पुराना मॉडल है उस पे मुझे लगता है कि इजीली आप रन कर सकते हो और इसमें भी आप टेक्स्ट और इमेज दोनों एज अ इनपुट दे सकते हो। सो लेट्स सी कि मैं इसको यहां पे डाउनलोड कर सकता हूं कि नहीं। देखो यहां पर यह है। मैं इसको ईजीली')]

# %%
llm = ChatOllama(
    model="qwen3:1.7b",
    temperature=0.3
)

# %%
prompt = PromptTemplate(
    template="""
        You are a Helpful Assistant
        Answer only from provided transcript Context in English Only
        if the context is inefficient , just say you dont know.

        {context},
        Question:{question}
    """,
    input_variables=["context", "question"]
)

# %%
question = "Is there any charges on Ollama?"
retrieved_docs = retriever.invoke(question)

# %%
context_text="\n\n".join(doc.page_content for doc in retrieved_docs)

# %%
final_prompt = prompt.invoke({"context": context_text,"question": question})

final_prompt
# Out:
# StringPromptValue(text='\n        You are a Helpful Assistant\n        Answer only from provided transcript Context in English Only\n        if the context is inefficient , just say you dont know.\n\n        को यूज़ कर सकते हो। इस मॉडल से कंटीन्यूअसली चैट कर सकते हो। अब क्योंकि इस मॉडल को मैंने लोकली अपने सिस्टम पे डाउनलोड कर लिया है। तो अब मुझे इसको यूज़ करने के लिए इंटरनेट का जरूरत ही नहीं है। लेट मी टर्न ऑफ माय Wi-Fi। ठीक है? Wi-Fi बं
िए आपको चाहिए होगा इंटरनेट कनेक्टिविटी। बिना इंटरनेट का आप यूज़ नहीं कर सकते हो। ठीक है? जैसे देखो यहां पे मैंने GPT ओs 120 भी सेलेक्ट कर लिया है। और यहां पे इसमें मुझे थिंकिंग का भी ऑप्शन मिल रहा है। कितना चाहते हो थिंकिंग करना। तो यहां पे मीडियम सिलेक्टेड है। और अब मैं यहां पूछता हूं व्हिच मॉडल आर यू? ओके लेट्स सी क्या रिस्पांस आता है। देखो यहां पे रिस्पांस आने लगा। आई एम बिल्ट ऑन ओपन GPT4 आर्किटेक्चर स्पेसिफिकली GPT4 टर्बो वेरिएंट दैट पावर्स दिस चैट। तो यहां पे स्पेसिफिकली ये मॉडल नेम तो नहीं बता रहा है पर बता रहा है कि हां ओपनक जीपीटी4\n\nजो सिर्फ 1GB का है। आप इसको ऑब्वियसली अपने लैपटॉप पे तो रन कर ही सकते हो। कितना भी पुराना मॉडल है उस पे मुझे लगता है कि इजीली आप रन कर सकते हो और इसमें भी आप टेक्स्ट और इमेज दोनों एज अ इनपुट दे सकते हो। सो लेट्स सी कि मैं इसको यहां पे डाउनलोड कर सकता हूं कि नहीं। देखो यहां पर यह है। मैं इसको ईजीली सेलेक्ट करके इसको भी यूज कर सकता हूं। आप ऐसे छोटे मॉडल्स को छोटे-मोटे कामों के लिए जैसे कि अगर आपको सिंपल-सिंपल क्वेश्चंस पूछना है या आपको ईमेल को और बेहतर बनाना है, स्पेलिंग मिस्टेक ठीक करना है, तो वहां उन सब कामों के लिए आप इस मॉडल को यूज़ कर सकते हो। अब यहां पे आप जो मॉडल्स डाउनलोड कर रहे हो, आप उसको यूज़ कर सकते हो अलग-अलग एप्स में भी। अगर यहां लॉन्च पे जाओगे तो आपको यहां पे ओपन क्लो क्लाउड कोडक्स ओपन कोड इस तरह के जो एप्लीकेशनेशंस है उसको लॉन्च करने के लिए ओ लामा के थ्रू उसका कमांड मिल रहा  ...

# %%
answer = llm.invoke(final_prompt)
print(answer.content)

# %%
from langchain_core.runnables import RunnableParallel,RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
def format_doc(retrieved_doc):
    context_text="\n\n".join(doc.page_content for doc in retrieved_docs)
    return context_text

# %%
parallel_chain = RunnableParallel({
    'context':retriever|RunnableLambda(format_doc),
    'question': RunnablePassthrough()
})

# %%
parallel_chain.invoke('How Earth looks from space?')
# Out:
# {'context': "bumped up into each other and and made the you know made the mountains. Um and then the coast is obviously cool because you can see particularly on the east side uh when the rivers run off how they interact with the water on that side, the different colors and swirls from that side. And then at one point in time I took a picture of the interaction between India and how do we call it nowadays? Sri Lanka. >> Yeah. >> Um um and it seems like there's a connection there. I'll just say that. [laughter] >> I'll say that. I think I think that picture took a there was a little bit of a discussion about that picture, but it it looks like there is you know they absolutely could be connected. >> Yeah, there must be some >> there's something there. >> There's something connected. [laughter] Maybe we leave it out there like that. >> Yeah. Yeah. Leave it out there. >> What's And when you look out of the window, okay, this is my sci-fi brain talking, okay? So, just don't doubt me on this question, but I'm still going to be What's the strangest thing you've seen in the space which you think is going to be hard to believe for people here? >> Oh, interesting. Um, uh, two different things that were different or have been different. Um there's a lot of communication satellites up there now, Starlinks. >> And so you can this time uh 10 from 10 years ago, they fly across the the view like you see the stars of course as they're coming, but they fly across the view which is like whoa, what where did these all come from? And um there's which is great because there's a lot of communication now on Earth because we have these constellations of satellites. But there is it was an impression like there is a lot of stuff in orbits around the planet. Um the other thing which was really cool this time uh and we were able it's hard to see with the naked eye but we have some really great cameras and we were able to take pictures not me in particular but Don Pettit and and Matt Dominic of blue jets and red sprites coming out of a thundercloud like energy coming up. Um, it's out there because Nicole Ayes took some after we left, too. And I think those are posted. Um, just amazing that we were able to take pictures of energy coming out of a thundercloud and out of lightning. >> Wow. >> Yeah, that was pretty amazing. So, there's there's just and I had no idea those things existed. People knew they were existing, but it was hard to actually document it. And now the cameras that we have, we can we can document that. So, all of that's pretty pretty amazing. Don was able to also with his camera because these are things you can see. You can see the Milky Way. Like it's amazing to see so many billions of stars out there, but he was and it's hard to take good pictures, pinpoint pictures of stars because we're moving so fast. >> Mhm. [clears throat] >> He rigged up with a little gear box, uh, something to copy the orbital rate as we were flying so he could pinpoint the pictures, pinpoint the\n\nHow does India look like from this space? [music] >> Looking at India in the daytime, colors are amazing. The Himalayas are absolutely amazing. You can see uh when the rivers run off, how they interact. Night, India is pretty spectacular. The cities are lit up and all those lights seems to be like connected. Sita Williams and Buchil are still stuck in space and are not expected to return. >> 10-day test flight turned into a 9-monl long mission in space. >> This after their Boeing Starlininer faced ruster failure. >> This time, this flight, the last one, was pretty messed up. >> Once after we launched and then we got to the space station, we knew we weren't going to come home as planned. We knew it would be six more months. When you're in space and coming home is a byproduct of this business, it's risky. >> [music] >> How many situations do you plan for? >> Oh gosh, hundreds. Trained for two years for a launch of a spacecraft cuz we go through with our control team. Hey, w ...
#  'question': 'How Earth looks from space?'}

# %%
parser = StrOutputParser()

# %%
main_chain = parallel_chain | prompt | llm | parser

# %%
main_chain.invoke('Can you summarize the video?')
# Out:
# 'The video transcript features an astronaut discussing various aspects of her experiences in space. She describes observations of Earth from space, including the amazing colors of India, the Himalayas, the interaction of rivers with coastal waters, and new sightings of fishing boats with bright lights at night off the west coast of India. She notes how India\'s cities are spectacularly lit up at night, resembling connected nerves.\n\nThe astronaut also shares personal experiences and challenges:\n*   **Unexpected Mission Length:** A 10-day test flight turned into a 9-month mission due to a booster failure, leading to a prolonged stay in space.\n*   **Risks and Dangers:** She recounts being woken up due to a satellite exploding below them, creating a debris field, and the crew having to go to their "safe haven" spacecraft. She also mentions the hundreds of situations they train for, including potential failures.\n*   **Emotional Aspects:** She discusses how fellow astronauts become like family, admits to crying in space due to missing people and her dog, and the feeling of nausea upon returning to Earth as her neurovestibular system readjusts.\n*   **Motivation and Beliefs:** She reflects on the Columbia disaster and how it strengthened the desire to continue exploration in memory of those lost. She carries Lord Ganesh as a good luck charm and believes her father\'s "spark" is always watching her. She also expresses a strong belief in the existence of life elsewhere in the universe.\n*   **Unique Sightings:** Beyond Earth\'s geography, she mentions the increased number of Starlink communication satellites, and the amazing experience of capturing images of "blue jets" and "red sprites" coming out of thunderclouds, which were previously hard to document. She also talks about the incredible view of the Milky Way from space.'
